# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('books.csv')
df.head()
# Out:
#                                                                                                                 bookID  \
# bookID title                                              authors                     rating pages NaN NaN NaN     NaN
# 1      Harry Potter and the Half-Blood Prince (Harry P... J.K. Rowling/Mary GrandPr̩ 4.57   652   NaN NaN NaN     NaN
# 2      Harry Potter and the Order of the Phoenix (Harr... J.K. Rowling/Mary GrandPr̩ 4.49   870   NaN NaN NaN     NaN
# 4      Harry Potter and the Chamber of Secrets (Harry ... J.K. Rowling                4.42   352   NaN NaN NaN     NaN
# 5      Harry Potter and the Prisoner of Azkaban (Harry... J.K. Rowling/Mary GrandPr̩ 4.56   435   NaN NaN NaN     NaN
#
#                                                                                                                 title  \
# bookID title                                              authors                     rating pages NaN NaN NaN    NaN
# ...
